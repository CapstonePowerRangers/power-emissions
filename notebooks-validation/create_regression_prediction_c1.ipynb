# %%
# uses pyCaret to find optimise model and tune it
# check version
from library.common import Core
core = Core()

from pycaret.utils import version
from pycaret.regression import *
version()
# Out:
# '2.3.5'

# %%
# Set up pyCaret Regression
# load dataset
regions_list  = core.list_of_regions
r = 1
cluster = regions_list[r]
print(cluster)

data = core.get_cluster_regression_datas(cluster = cluster, first = core.start_year, last = core.stop_year)
reg0 = setup(data, target = 'co2', session_id=123, log_experiment=True,
             normalize = core.regression_normalize, normalize_method = core.normalize_method,
             remove_outliers = core.remove_outliers, outliers_threshold = core.outliers_threshold,
             verbose = False, silent = core.silent_mode,
             experiment_name= f'carbon emission Cluster {r}')

best_model = compare_models(fold= core.regression_cv, sort = core.error_optimise, round = 0)
# Out:
# <style type="text/css">
# #T_00eaa_ th {
#   text-align: left;
# }
# #T_00eaa_row0_col0, #T_00eaa_row1_col0, #T_00eaa_row1_col1, #T_00eaa_row1_col2, #T_00eaa_row1_col3, #T_00eaa_row2_col0, #T_00eaa_row2_col1, #T_00eaa_row2_col2, #T_00eaa_row2_col3, #T_00eaa_row3_col0, #T_00eaa_row3_col1, #T_00eaa_row3_col2, #T_00eaa_row3_col3, #T_00eaa_row4_col0, #T_00eaa_row4_col1, #T_00eaa_row4_col2, #T_00eaa_row4_col3, #T_00eaa_row5_col0, #T_00eaa_row5_col1, #T_00eaa_row5_col2, #T_00eaa_row5_col3, #T_00eaa_row6_col0, #T_00eaa_row6_col1, #T_00eaa_row6_col2, #T_00eaa_row6_col3, #T_00eaa_row7_col0, #T_00eaa_row7_col1, #T_00eaa_row7_col2, #T_00eaa_row7_col3, #T_00eaa_row8_col0, #T_00eaa_row8_col1, #T_00eaa_row8_col2, #T_00eaa_row8_col3, #T_00eaa_row9_col0, #T_00eaa_row9_col1, #T_00eaa_row9_col2, #T_00eaa_row9_col3, #T_00eaa_row10_col0, #T_00eaa_row10_col1, #T_00eaa_row10_col2, #T_00eaa_row10_col3, #T_00eaa_row11_col0, #T_00eaa_row11_col1, #T_00eaa_row11_col2, #T_00eaa_row11_col3, #T_00eaa_row12_col0, #T_00eaa_row12_col1, #T_00eaa_row12_col2, #T_00eaa_row12_col3, #T_00eaa_row13_col0, #T_00eaa_row13_col1, #T_00eaa_row13_col2, #T_00eaa_row13_col3, #T_00eaa_row14_col0, #T_00eaa_row14_col1, #T_00eaa_row14_col2, #T_00eaa_row14_col3, #T_00eaa_row15_col0, #T_00eaa_row15_col1, #T_00eaa_row15_col2, #T_00eaa_row15_col3, #T_00eaa_row15_col4, #T_00eaa_row16_col0, #T_00eaa_row16_col1, #T_00eaa_row16_col2, #T_00eaa_row16_col3, #T_00eaa_row16_col4, #T_00eaa_row17_col0, #T_00eaa_row17_col1, #T_00eaa_row17_col2, #T_00eaa_row17_col3, #T_00eaa_row17_col4 {
#   text-align: left;
# }
# #T_00eaa_row0_col1, #T_00eaa_row0_col2, #T_00eaa_row0_col3, #T_00eaa_row0_col4, #T_00eaa_row0_col5, #T_00eaa_row0_col6, #T_00eaa_row1_col4, #T_00eaa_row1_col5, #T_00eaa_row1_col6, #T_00eaa_row2_col4, #T_00eaa_row2_col5, #T_00eaa_row2_col6, #T_00eaa_row3_col4, #T_00eaa_row3_col5, #T_00eaa_row3_col6, #T_00eaa_row4
row5_col7" class="data row5 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_00eaa_level0_row6" class="row_heading level0 row6" >llar</th>
#       <td id="T_00eaa_row6_col0" class="data row6 col0" >Lasso Least Angle Regression</td>
#       <td id="T_00eaa_row6_col1" class="data row6 col1" >622</td>
#       <td id="T_00eaa_row6_col2" class="data row6 col2" >566241</td>
#       <td id="T_00eaa_row6_col3" class="data row6 col3" >746</td>
#       <td id="T_00eaa_row6_col4" class

# %%
# selected_model = 'et'
# model = create_model(selected_model)
# tuned_model = tune_model(model, n_iter=100, optimize = core.error_optimise, round = 1)

# %%
selected_model = 'gbr'
model = create_model(selected_model)
tuned_model = tune_model(model, n_iter=100, optimize = 'MSE', round = 1)
# Out:
# <style type="text/css">
# #T_902c5_row10_col0, #T_902c5_row10_col1, #T_902c5_row10_col2, #T_902c5_row10_col3, #T_902c5_row10_col4, #T_902c5_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_902c5_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_902c5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_902c5_row0_col0" class="data row0 col0" >181.7</td>
#       <td id="T_902c5_row0_col1" class="data row0 col1" >73334.7</td>
#       <td id="T_902c5_row0_col2" class="data row0 col2" >270.8</td>
#       <td id="T_902c5_row0_col3" class="data row0 col3" >1.0</td>
#       <td id="T_902c5_row0_col4" class="data row0 col4" >0.0</td>
#       <td id="T_902c5_row0_col5" class="data row0 col5" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_902c5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_902c5_row1_col0" class="data row1 col0" >342.4</td>
#       <td id="T_902c5_row1_col1" class="data row1 col1" >217677.1</td>
#       <td id="T_902c5_row1_col2" class="data row1 col2" >466.6</td>
#       <td id="T_902c5_row1_col3" class="data row1 col3" >1.0</td>
#       <td id="T_902c5_row1_col4" class="data row1 col4" >0.1</td>
#       <td id="T_902c5_row1_col5" class="data row1 col5" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_902c5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_902c5_row2_col0" class="data row2 col0" >183.9</td>
#       <td id="T_902c5_row2_col1" class="data row2 col1" >48594.7</td>
#       <td id="T_902c5_row2_col2" class="data row2 col2" >220.4</td>
#       <td id="T_902c5_row2_col3" class="data row2 col3" >1.0</td>
#       <td id="T_902c5_row2_col4" class="data row2 col4" >0.0</td>
#       <td id="T_902c5_row2_col5" class="data row2 col5" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_902c5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_902c5_row3_col0" class="data row3 col0" >270.8</td>
#       <td id="T_902c5_row3_col1" class="data row3 col1" >125552.0</td>
#       <td id="T_902c5_row3_col2" class="data row3 col2" >354.3</td>
#       <td id="T_902c5_row3_col3" class="data row3 col3" >1.0</td>
#       <td id="T_902c5_row3_col4" class="data row3 col4" >0.1</td>
#       <td id="T_902c5_row3_col5" class="data row3 col5" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_902c5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_902c5_row4_col0" class="data row4 col0" >100.9</td>
#       <td id="T_902c5_row4_col1" class="data row4 col1" >10585.5</td>
#       <td id="T_902c5_row4_col2" class="data row4 col2" >102.9</td>
#       <td id="T_902c5_row4_col3" class="data row4 col3" >1.0</td>
#       <td id="T_902c5_row4_col4" class="data row4 col4" >0.0</td>
#       <td id="T_902c5_row4_col5" class="data row4 col5" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_902c5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_902c5_row5_col0" class="data row5 col0" >177.5</td>
#       <td id="T_902c5_row5_col1" class="data row5 col1" >50020.2</td>
#       <td id="T_902c5_row5_col2" class="data row5 col2" >223.7</td>
#       <td id="T_902c5_row5_col3" class="data row5 col3" >1.0</td>
#       <td id="T_902c5_row5_col4" class="data row5 col4" >0.0</td>
#       <td id="T_902c5_row5_col5" class="data row5 col5" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_902c5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_902c5_row6_col0" class="data row6 col0" >394.5</td>
#       <td id="T_902c5_row6_col1" class="data row6 col1" >185963.5</td>
#       <td id="T_902c5_row6_col2" class="data row6 col2" >431.2</td>
#       <td id="T_902c5_row6_col3" class="data row6 col3" >1.0</td>
#       <td id="T_902c5_row6_col4" class="data row6 col4" >0.0</td>
#       <td id="T_902c5_row6_col5" class="data row6 col5" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_902c5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_902c5_row7_col0" class="data row7 col0" >50.9</td>
#       <td id="T_902c5_row7_col1" class="data row7 col1" >4744.6</td>
#       <td id="T_902c5_row7_col2" class="data row7 col2" >68.9</td>
#       <td id="T_902c5_row7_col3" class="data row7 col3" >1.0</td>
#       <td id="T_902c5_row7_col4" class="data row7 col4" >0.0</td>
#       <td id="T_902c5_row7_col5" class="data row7 col5" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_902c5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_902c5_row8_col0" class="data row8 col0" >291.6</td>
#       <td id="T_902c5_row8_col1" class="data row8 col1" >92106.4</td>
#       <td id="T_902c5_row8_col2" class="data row8 col2" >303.5</td>
#       <td id="T_902c5_row8_col3" class="data row8 col3" >1.0</td>
#       <td id="T_902c5_row8_col4" class="data row8 col4" >0.0</td>
#       <td id="T_902c5_row8_col5" class="data row8 col5" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_902c5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_902c5_row9_col0" class="data row9 col0" >178.4</td>
#       <td id="T_902c5_row9_col1" class="data row9 col1" >52969.4</td>
#       <td id="T_902c5_row9_col2" class="data row9 col2" >230.2</td>
#       <td id="T_902c5_row9_col3" class="data row9 col3" >1.0</td>
#       <td id="T_902c5_row9_col4" class="data row9 col4" >0.0</td>
#       <td id="T_902c5_row9_col5" class="data row9 col5" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_902c5_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_902c5_row10_col0" class="data row10 col0" >217.3</td>
#       <td id="T_902c5_row10_col1" class="data row10 col1" >86154.8</td>
#       <td id="T_902c5_row10_col2" class="data row10 col2" >267.2</td>
#       <td id="T_902c5_row10_col3" class="data row10 col3" >1.0</td>
#       <td id="T_902c5_row10_col4" class="data row10 col4" >0.0</td>
#       <td id="T_902c5_row10_col5" class="data row10 col5" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_902c5_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_902c5_row11_col0" class="data row11 col0" >101.1</td>
#       <td id="T_902c5_row11_col1" class="data row11 col1" >67207.1</td>
#       <td id="T_902c5_row11_col2" class="data row11 col2" >121.4</td>
#       <td id="T_902c5_row11_col3" class="data row11 col3" >0.0</td>
#       <td id="T_902c5_row11_col4" class="data row11 col4" >0.0</td>
#       <td id="T_902c5_row11_col5" class="data row11 col5" >0.0</td>
#     </tr>
#   </tbody>
# </table>

# %%
# selected_model = 'rf'
# model = create_model(selected_model)
# tuned_model = tune_model(model, n_iter=100, optimize = 'MSE', round = 1)

# %%
tuned_model
# Out:
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.05, loss='ls',
#                           max_depth=11, max_features=1.0, max_leaf_nodes=None,
#                           min_impurity_decrease=0.05, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=7,
#                           min_weight_fraction_leaf=0.0, n_estimators=170,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=123, subsample=0.3, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
plot_model(tuned_model)

# %%
plot_model(tuned_model, plot = 'error')

# %%
plot_model(tuned_model, plot = 'feature')

# %%
evaluate_model(tuned_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
try:
    interpret_model(tuned_model)
except:
    print('No plot for this model')
# Out:
# No plot for this model

# %%
try:
    interpret_model(tuned_model, plot = 'correlation')
except:
    print('No plot for this model')
# Out:
# No plot for this model

# %%
try:
    interpret_model(tuned_model, plot = 'reason', observation = 12)
except:
    print('No plot for this model')
# Out:
# No plot for this model

# %%
final_model = finalize_model(tuned_model)
data = core.get_forecasts()
data = data.drop(columns =  ['co2'])
data_unseen = data.loc[data.cluster.eq(cluster),]

# generate predictions on unseen data
predictions = predict_model(final_model, data = data_unseen)
predictions = predictions.rename(columns = {'Label': 'co2'})
predictions[['year', 'co2']]
# Out:
#    year           co2
# 0  2017  14999.606280
# 1  2018  14996.554923
# 2  2019  15088.549497
# 3  2020  15215.497303
