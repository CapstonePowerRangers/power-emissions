# %%
from library.common import Core

core = Core()
df = core.get_cluster_data(2007)
df
# Out:
#       iso_code  year      co2  consumption_co2  trade_co2  \
# 61         AFG  2007    2.269            0.000      0.000
# 155        ALB  2007    3.829            5.406      1.578
# 265        DZA  2007  108.402            0.000      0.000
# 295        AND  2007    0.539            0.000      0.000
# 369        AGO  2007   24.977            0.000      0.000
# ...        ...   ...      ...              ...        ...
# 22954      MCO  2007    0.000            0.000      0.000
# 22955      MNP  2007    0.000            0.000      0.000
# 22956      SMR  2007    0.000            0.000      0.000
# 22957      VIR  2007    0.000            0.000      0.000
# 22958      XKX  2007    0.000            0.000      0.000
#
#        co2_per_unit_energy  coal_co2  cement_co2  flaring_co2  gas_co2  ...  \
# 61                   0.241     0.749       0.012        0.000    0.308  ...
# 155                  0.152     0.073       0.348        0.000    0.033  ...
# ...
